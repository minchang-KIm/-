# %% [markdown]
# <a href="https://colab.research.google.com/github/minchang-KIm/-/blob/master/202020717_%EA%B9%80%EB%AF%BC%EC%B0%BD_rev10.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# IMPORTANT: SOME KAGGLE DATA SOURCES ARE PRIVATE
# RUN THIS CELL IN ORDER TO IMPORT YOUR KAGGLE DATA SOURCES.
import kagglehub
kagglehub.login()
# Out:
# VBox(children=(HTML(value='<center> <img\nsrc=https://www.kaggle.com/static/images/site-logo.png\nalt=\'Kaggle…

# %%
# IMPORTANT: RUN THIS CELL IN ORDER TO IMPORT YOUR KAGGLE DATA SOURCES,
# THEN FEEL FREE TO DELETE THIS CELL.
# NOTE: THIS NOTEBOOK ENVIRONMENT DIFFERS FROM KAGGLE'S PYTHON
# ENVIRONMENT SO THERE MAY BE MISSING LIBRARIES USED BY YOUR
# NOTEBOOK.

#ai_challenge_path = kagglehub.competition_download('2024-ai-challenge')

#print('Data source import complete.')

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# # 1: 라이브러리 임포트

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from torch.utils.data import DataLoader, Dataset
import torchvision.transforms as transforms
# !pip install torchsummary
from torchsummary import summary
from sklearn.model_selection import ParameterGrid
import multiprocessing  # 추가된 부분
# Out:
# Requirement already satisfied: torchsummary in /usr/local/lib/python3.10/dist-packages (1.5.1)

# %% [markdown]
# # 2: 커스텀 Dataset 정의

# %%
# - 이미지와 레이블을 전달받아 학습 및 검증을 위한 데이터를 제공
class CustomDataset(Dataset):
    def __init__(self, images, labels, transform=None):
        self.images = images
        self.labels = labels
        self.transform = transform

    def __len__(self):
        return len(self.images)

    def __getitem__(self, idx):
        image = self.images[idx]
        label = self.labels[idx]

        if self.transform:
            image = self.transform(image)

        return image, label

# %% [markdown]
# # 3: Squeeze-and-Excitation 모듈 정의

# %%
# SE Block 정의
class SqueezeExcitation(nn.Module):
    def __init__(self, in_channels, reduction=4):
        super(SqueezeExcitation, self).__init__()
        self.fc1 = nn.Conv2d(in_channels, in_channels // reduction, kernel_size=1)
        self.fc2 = nn.Conv2d(in_channels // reduction, in_channels, kernel_size=1)

    def forward(self, x):
        out = F.adaptive_avg_pool2d(x, 1)
        out = F.relu(self.fc1(out))
        out = torch.sigmoid(self.fc2(out))
        return x * out

# %% [markdown]
# # 4: Conv-BN-ReLU 모듈 정의

# %%
# - 일반적인 Convolution-BatchNorm-활성화 함수 블록
class ConvBNReLU(nn.Module):
    def __init__(self, in_channels, out_channels, stride):
        super(ConvBNReLU, self).__init__()
        self.conv = nn.Conv2d(in_channels, out_channels, kernel_size=3, stride=stride, padding=1, bias=False)
        self.bn = nn.BatchNorm2d(out_channels)
        self.relu = nn.ReLU(inplace=True)

    def forward(self, x):
        return self.relu(self.bn(self.conv(x)))

# %% [markdown]
# # 5: Inverted Residual Block 정의

# %%
# Inverted Residual Block 정의
class InvertedResidual(nn.Module):
    def __init__(self, in_channels, out_channels, stride, expand_ratio=4):
        super(InvertedResidual, self).__init__()
        self.stride = stride
        hidden_dim = in_channels * expand_ratio

        # stride가 1이고 in_channels와 out_channels가 같으면 skip connection을 사용
        self.use_res_connect = stride == 1 and in_channels == out_channels

        # 1x1 Conv -> Expansion
        self.conv1 = nn.Conv2d(in_channels, hidden_dim, kernel_size=1, bias=False)
        self.bn1 = nn.BatchNorm2d(hidden_dim)

        # Depthwise 3x3 Conv
        self.conv2 = nn.Conv2d(hidden_dim, hidden_dim, kernel_size=3, stride=stride, padding=1, groups=hidden_dim, bias=False)
        self.bn2 = nn.BatchNorm2d(hidden_dim)

        # SE Block 적용
        self.se = SqueezeExcitation(hidden_dim)

        # 1x1 Conv -> Projection
        self.conv3 = nn.Conv2d(hidden_dim, out_channels, kernel_size=1, bias=False)
        self.bn3 = nn.BatchNorm2d(out_channels)

    def forward(self, x):
        # 확장 단계
        out = F.relu(self.bn1(self.conv1(x)), inplace=True)

        # Depthwise Conv + SE Block
        out = F.relu(self.bn2(self.conv2(out)), inplace=True)
        out = self.se(out)  # Squeeze-and-Excitation 적용

        # 축소 단계
        out = self.bn3(self.conv3(out))

        # Skip connection 적용
        if self.use_res_connect:
            return x + out  # 입력과 출력을 더함 (Residual 연결)
        else:
            return out  # skip connection이 없는 경우

# %% [markdown]
# # Squeeze-and-Excitation block

# %%
class SqueezeExcitation(nn.Module):
    def __init__(self, in_channels, reduction_ratio=16):
        super(SqueezeExcitation, self).__init__()
        # 최소 크기 보장
        reduced_channels = max(1, in_channels // reduction_ratio)
        self.fc1 = nn.Linear(in_channels, reduced_channels)
        self.fc2 = nn.Linear(reduced_channels, in_channels)

    def forward(self, x):
        batch, channels, _, _ = x.size()
        y = F.adaptive_avg_pool2d(x, 1).view(batch, channels)

        # Swish 사용: x * sigmoid(x)
        y = self.fc1(y)
        y = y * torch.sigmoid(y)  # Swish 적용
        y = self.fc2(y)
        y = y * torch.sigmoid(y)  # Swish 적용
        y = y.view(batch, channels, 1, 1)
        return x * y

# %% [markdown]
# # 6: NOLA 모델 정의

# %%
# NOLA_MobileNetV3 모델 정의
class NOLA_MobileNetV3(nn.Module):
    def __init__(self, num_classes=100):
        super(NOLA_MobileNetV3, self).__init__()

        # 기본 Conv 레이어
        self.conv1 = nn.Conv2d(3, 16, kernel_size=3, stride=2, padding=1, bias=False)
        self.bn1 = nn.BatchNorm2d(16)

        # Inverted Residual Blocks와 SE Block 사용
        self.block1 = InvertedResidual(16, 24, stride=2, expand_ratio=3)
        self.block2 = InvertedResidual(24, 32, stride=2, expand_ratio=3)
        self.block3 = InvertedResidual(32, 64, stride=2, expand_ratio=4)
        self.block4 = InvertedResidual(64, 128, stride=2, expand_ratio=4)

        # GAP 적용
        self.gap = nn.AdaptiveAvgPool2d((1, 1))
        self.fc = nn.Linear(128, num_classes)

    def forward(self, x):
        x = F.relu(self.bn1(self.conv1(x)), inplace=True)
        x = self.block1(x)
        x = self.block2(x)
        x = self.block3(x)
        x = self.block4(x)
        x = self.gap(x)
        x = x.view(x.size(0), -1)
        x = self.fc(x)
        return x

model = NOLA_MobileNetV3().cuda()
summary(model, (3, 224, 224))  # 모델 구조 요약
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1         [-1, 16, 112, 112]             432
#        BatchNorm2d-2         [-1, 16, 112, 112]              32
#             Conv2d-3         [-1, 48, 112, 112]             768
#        BatchNorm2d-4         [-1, 48, 112, 112]              96
#             Conv2d-5           [-1, 48, 56, 56]             432
#        BatchNorm2d-6           [-1, 48, 56, 56]              96
#             Linear-7                    [-1, 3]             147
#             Linear-8                   [-1, 48]             192
#  SqueezeExcitation-9           [-1, 48, 56, 56]               0
#            Conv2d-10           [-1, 24, 56, 56]           1,152
#       BatchNorm2d-11           [-1, 24, 56, 56]              48
#  InvertedResidual-12           [-1, 24, 56, 56]               0
#            Conv2d-13           [-1, 72, 56, 56]           1,728
#       BatchNorm2d-14           [-1, 72, 56, 56]             144
#            Conv2d-15           [-1, 72, 28, 28]             648
#       BatchNorm2d-16           [-1, 72, 28, 28]             144
#            Linear-17                    [-1, 4]             292
#            Linear-18                   [-1, 72]             360
# SqueezeExcitation-19           [-1, 72, 28, 28]               0
#            Conv2d-20           [-1, 32, 28, 28]           2,304
#       BatchNorm2d-21           [-1, 32, 28, 28]              64
#  InvertedResidual-22           [-1, 32, 28, 28]               0
#            Conv2d-23          [-1, 128, 28, 28]           4,096
#       BatchNorm2d-24          [-1, 128, 28, 28]             256
#            Conv2d-25          [-1, 128, 14, 14]           1,152
#       BatchNorm2d-26          [-1, 128, 14, 14]             256
#            Linear-27                    [-1, 8]           1,032
#            Linear-28                  [-1, 128]           1,152
# SqueezeExcitation-29          [-1, 128, 14, 14]               0
#            Conv2d-30           [-1, 64, 14, 14]           8,192
#       BatchNorm2d-31           [-1, 64, 14, 14]             128
#  InvertedResidual-32           [-1, 64, 14, 14]               0
#            Conv2d-33          [-1, 256, 14, 14]          16,384
#       BatchNorm2d-34          [-1, 256, 14, 14]             512
#            Conv2d-35            [-1, 256, 7, 7]           2,304
#       BatchNorm2d-36            [-1, 256, 7, 7]             512
#            Linear-37                   [-1, 16]           4,112
#            Linear-38                  [-1, 256]           4,352
# SqueezeExcitation-39            [-1, 256, 7, 7]               0
#            Conv2d-40            [-1, 128, 7, 7]          32,768
#       BatchNorm2d-41            [-1, 128, 7, 7]             256
#  InvertedResidual-42            [-1, 128, 7, 7]               0
# AdaptiveAvgPool2d-43            [-1, 128, 1, 1]               0
#            Linear-44                  [-1, 100]          12,900
# ================================================================
# Total params: 99,443
# Trainable params: 99,443
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.57
# Forward/backward pass size (MB): 26.32
# Params size (MB): 0.38
# Estimated Total Size (MB): 27.28
# ----------------------------------------------------------------

# %% [markdown]
# # NOLA LinearLayer

# %%
class GenerateParams(torch.autograd.Function):
    # Generate parameters on the fly with random basis

    @staticmethod
    def forward(ctx, coefficients, out_dim, in_dim, seed):
        num_basis = coefficients.shape[0]
        Out = torch.zeros(out_dim, in_dim).to(coefficients.device)
        rand_seed = torch.randint(int(1e10), (1,))
        torch.manual_seed(seed)

        W = torch.zeros(num_basis, out_dim, in_dim,
                        device=coefficients.device, dtype=coefficients.dtype)
        nn.init.uniform_(W, a=-1.0, b=1.0)
        Out = torch.einsum('b,boi->oi', coefficients, W)

        params = torch.autograd.Variable(torch.tensor([out_dim, in_dim, seed]))
        ctx.save_for_backward(coefficients, params)
        torch.manual_seed(rand_seed)
        return Out

    @staticmethod
    def backward(ctx, grad_output):
        coefficients, params = ctx.saved_tensors
        num_basis = coefficients.shape[0]

        out_dim, in_dim, seed = params
        rand_seed = torch.randint(int(1e10), (1,))
        torch.manual_seed(seed)
        grad_coefficients = torch.empty(0).to(grad_output.device)

        W = torch.zeros(num_basis, out_dim, in_dim,
                        device=coefficients.device, dtype=coefficients.dtype)
        nn.init.uniform_(W, a=-1.0, b=1.0)
        W = W.permute(1, 2, 0).reshape(-1, num_basis)
        grad_coefficients = torch.einsum('d,dl->l', grad_output.flatten(), W)

        torch.manual_seed(rand_seed)
        return grad_coefficients, None, None, None


# NOLA Linear Layer 정의 수정
class NOLALinear(nn.Linear):
    def __init__(self, in_features: int, out_features: int, coefficients: torch.Tensor, seed: int, num_basis=128, **kwargs):
        super(NOLALinear, self).__init__(in_features, out_features, **kwargs)
        self.num_basis = num_basis
        self.generate_params = GenerateParams.apply
        self.coefficients = nn.Parameter(coefficients, requires_grad=True)
        self.seed = nn.Parameter(torch.tensor(seed), requires_grad=False)
        self.weight.requires_grad = False

    def extra_repr(self) -> str:
        return 'in_features={}, out_features={}, num_basis={}'.format(
            self.in_features, self.out_features, self.num_basis)

    def forward(self, x: torch.Tensor):
        W = self.generate_params(self.coefficients,
                          self.out_features,
                          self.in_features,
                          self.seed) + self.weight
        return x @ W.t()

# %% [markdown]
# # 7: 데이터 전처리

# %%
# 여러 Augmentation 기법 적용 (좌우반전, 회전, 크기 조절 등)
transform = transforms.Compose([
    transforms.ToPILImage(),  # 이 부분을 가장 마지막에 두어야 합니다.
    transforms.RandomHorizontalFlip(),
    #transforms.RandomRotation(10),
    #transforms.RandomCrop(224, padding=4),
    #transforms.ColorJitter(brightness=0.2, contrast=0.2, saturation=0.2, hue=0.1),
    transforms.ToTensor(),  # 이미지를 텐서로 변환
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225]),  # 이미지 정규화
    #transforms.RandomErasing()  # RandomErasing 추가
])

# %% [markdown]
# # 8: 데이터 로딩

# %%
# - 학습 및 검증 데이터 로드 (Kaggle에서 데이터 불러오기)
train = np.load('drive/MyDrive/Colab Notebooks/AiChallenge/2024-ai-challenge/trainset.npy')
label = np.load('drive/MyDrive/Colab Notebooks/AiChallenge/2024-ai-challenge/trainlabel.npy')

# 학습 및 검증 데이터 분할
X_train, X_val, y_train, y_val = train_test_split(train, label, test_size=0.2, random_state=42)
train_dataset = CustomDataset(X_train, y_train, transform=transform)
train_loader = DataLoader(train_dataset, batch_size=1024, shuffle=True, num_workers=multiprocessing.cpu_count())

val_dataset = CustomDataset(X_val, y_val, transform=transform)
val_loader = DataLoader(val_dataset, batch_size=1024, shuffle=False, num_workers=multiprocessing.cpu_count())

# %% [markdown]
# # 10: 학습 준비

# %%
import torch
import torch.nn as nn
import torch.optim as optim
import numpy as np
import pandas as pd
from tqdm import tqdm
from sklearn.model_selection import KFold
from torch.utils.data import DataLoader, Subset

# Hyperparameters
num_epochs = 500  # 최대 Epoch 수
learning_rate = 0.01  # 초기 학습률
weight_decay = 1e-4  # weight decay (L2 정규화)
batch_size = 1024

# 손실 함수 및 옵티마이저
criterion = nn.CrossEntropyLoss()

# K-Fold Cross Validation
kf = KFold(n_splits=5, shuffle=True, random_state=42)

# 최상의 모델 가중치를 저장하기 위한 변수
best_val_accuracy = 0
best_model_state = None

# K-Fold 학습 루프
for fold, (train_idx, val_idx) in enumerate(kf.split(train_dataset)):
    print(f'\nFold {fold + 1}/{kf.n_splits}')

    # Train/Validation Subset 생성
    train_subset = Subset(train_dataset, train_idx)
    val_subset = Subset(train_dataset, val_idx)

    # DataLoader 설정
    train_loader = DataLoader(train_subset, batch_size=batch_size, shuffle=True, num_workers=4)
    val_loader = DataLoader(val_subset, batch_size=batch_size, shuffle=False, num_workers=4)

    # 모델 초기화
    model.cuda()  # GPU 사용

    # 옵티마이저 및 스케줄러 설정
    optimizer = optim.Adam(model.parameters(), lr=learning_rate, weight_decay=weight_decay)
    scheduler = optim.lr_scheduler.ReduceLROnPlateau(optimizer, mode='max', factor=0.5, patience=5, verbose=True)

    # Early Stopping 기준
    early_stopping_patience = 20
    early_stopping_counter = 0

    # - 모델 학습 및 검증을 수행하는 메인 루프
    for epoch in range(num_epochs):
        model.train()
        total_loss = 0
        correct = 0

        # 학습 루프
        for batch_features, batch_labels in train_loader:
            batch_features, batch_labels = batch_features.cuda(), batch_labels.cuda()
            optimizer.zero_grad()
            outputs = model(batch_features)
            loss = criterion(outputs, batch_labels)
            loss.backward()
            optimizer.step()

            total_loss += loss.item()
            _, predicted = torch.max(outputs, 1)
            correct += (predicted == batch_labels).sum().item()

        # 학습 결과 출력
        average_loss = total_loss / len(train_loader)
        train_accuracy = correct / len(train_subset)
        print(f'Epoch [{epoch + 1}/{num_epochs}], Loss: {average_loss:.4f}, Train Accuracy: {train_accuracy:.4f}')

        # 검증 루프
        model.eval()
        val_correct = 0
        with torch.no_grad():
            for val_features, val_labels in val_loader:
                val_features, val_labels = val_features.cuda(), val_labels.cuda()
                val_outputs = model(val_features)
                _, val_predicted = torch.max(val_outputs, 1)
                val_correct += (val_predicted == val_labels).sum().item()

        # 검증 정확도 출력
        val_accuracy = val_correct / len(val_subset)
        print(f'Validation Accuracy: {val_accuracy:.4f}')

        # 스케줄러를 통해 학습률 조정
        scheduler.step(val_accuracy)
        print("Current learning rate:", scheduler.get_last_lr())

        # Early Stopping 체크
        if val_accuracy > best_val_accuracy:
            best_val_accuracy = val_accuracy
            early_stopping_counter = 0
            best_model_state = model.state_dict()  # 현재 모델의 가중치 저장
            print(f"New best model saved at fold {fold + 1}, epoch {epoch + 1} with val accuracy: {val_accuracy:.4f}")
        else:
            early_stopping_counter += 1
            if early_stopping_counter >= early_stopping_patience:
                print(f"Early stopping at fold {fold + 1}, epoch {epoch + 1}")
                break

# 최상의 모델 가중치 저장
torch.save(best_model_state, 'best_model.pth')
print(f"Best model saved with validation accuracy: {best_val_accuracy:.4f}")
# Out:
# Fold 1/5
# /usr/local/lib/python3.10/dist-packages/torch/optim/lr_scheduler.py:60: UserWarning: The verbose parameter is deprecated. Please use get_last_lr() to access the learning rate.
#   warnings.warn(
# Epoch [1/500], Loss: 1.8900, Train Accuracy: 0.4775
# Validation Accuracy: 0.4329
# Current learning rate: [0.01]
# New best model saved at fold 1, epoch 1 with val accuracy: 0.4329
# Epoch [2/500], Loss: 1.7467, Train Accuracy: 0.5090
# Validation Accuracy: 0.4499
# Current learning rate: [0.01]
# New best model saved at fold 1, epoch 2 with val accuracy: 0.4499
# Epoch [3/500], Loss: 1.7426, Train Accuracy: 0.5131
# Validation Accuracy: 0.4502
# Current learning rate: [0.01]
# New best model saved at fold 1, epoch 3 with val accuracy: 0.4502
# Epoch [4/500], Loss: 1.7308, Train Accuracy: 0.5161
# Validation Accuracy: 0.4235
# Current learning rate: [0.01]
# Epoch [5/500], Loss: 1.7123, Train Accuracy: 0.5193
# Validation Accuracy: 0.4396
# Current learning rate: [0.01]
# Epoch [6/500], Loss: 1.7136, Train Accuracy: 0.5200
# Validation Accuracy: 0.4219
# Current learning rate: [0.01]
# Epoch [7/500], Loss: 1.7109, Train Accuracy: 0.5200
# Validation Accuracy: 0.4379
# Current learning rate: [0.01]
# Epoch [8/500], Loss: 1.7041, Train Accuracy: 0.5200
# Validation Accuracy: 0.4051
# Current learning rate: [0.01]
# Epoch [9/500], Loss: 1.6920, Train Accuracy: 0.5252
# Validation Accuracy: 0.4376
# Current learning rate: [0.005]
# Epoch [10/500], Loss: 1.5763, Train Accuracy: 0.5537
# Validation Accuracy: 0.4645
# Current learning rate: [0.005]
# New best model saved at fold 1, epoch 10 with val accuracy: 0.4645
# Epoch [11/500], Loss: 1.5169, Train Accuracy: 0.5720
# Validation Accuracy: 0.4635
# Current learning rate: [0.005]
# Epoch [12/500], Loss: 1.5074, Train Accuracy: 0.5706
# Validation Accuracy: 0.4636
# Current learning rate: [0.005]
# Epoch [13/500], Loss: 1.5084, Train Accuracy: 0.5741
# Validation Accuracy: 0.4572
# Current learning rate: [0.005]
# Epoch [14/500], Loss: 1.5093, Train Accuracy: 0.5698
# Validation Accuracy: 0.4619
# Current learning rate: [0.005]
# Epoch [15/500], Loss: 1.4965, Train Accuracy: 0.5782
# Validation Accuracy: 0.4679
# Current learning rate: [0.005]
# New best model saved at fold 1, epoch 15 with val accuracy: 0.4679
# Epoch [16/500], Loss: 1.4890, Train Accuracy: 0.5773
# Validation Accuracy: 0.4467
# Current learning rate: [0.005]
# Epoch [17/500], Loss: 1.4815, Train Accuracy: 0.5803
# Validation Accuracy: 0.4572
# Current learning rate: [0.005]
# Epoch [18/500], Loss: 1.4821, Train Accuracy: 0.5783
# Validation Accuracy: 0.4465
# Current learning rate: [0.005]
# Epoch [19/500], Loss: 1.4722, Train Accuracy: 0.5815
# Validation Accuracy: 0.4465
# Current learning rate: [0.005]
# Epoch [20/500], Loss: 1.4749, Train Accuracy: 0.5804
# Validation Accuracy: 0.4585
# Current learning rate: [0.005]
# Epoch [21/500], Loss: 1.4728, Train Accuracy: 0.5803
# Validation Accuracy: 0.4564
# Current learning rate: [0.0025]
# Epoch [22/500], Loss: 1.3843, Train Accuracy: 0.6051
# Validation Accuracy: 0.4789
# Current learning rate: [0.0025]
# New best model saved at fold 1, epoch 22 with val accuracy: 0.4789
# Epoch [23/500], Loss: 1.3497, Train Accuracy: 0.6165
# Validation Accuracy: 0.4681
# Current learning rate: [0.0025]
# Epoch [24/500], Loss: 1.3433, Train Accuracy: 0.6170
# Validation Accuracy: 0.4703
# Current learning rate: [0.0025]
# Epoch [25/500], Loss: 1.3362, Train Accuracy: 0.6173
# Validation Accuracy: 0.4666
# Current learning rate: [0.0025]
# Epoch [26/500], Loss: 1.3374, Train Accuracy: 0.6189
# Validation Accuracy: 0.4667
# Current learning rate: [0.0025]
# Epoch [27/500], Loss: 1.3284, Train Accuracy: 0.6177
# Validation Accuracy: 0.4641
# Current learning rate: [0.0025]
# Epoch [28/500], Loss: 1.3227, Train Accuracy: 0.6193
# Validation Accuracy: 0.4600
# Current learning rate: [0.00125]
# Epoch [29/500], Loss: 1.2745, Train Accuracy: 0.6346
# Validation Accuracy: 0.4701
# Current learning rate: [0.00125]
# Epoch [30/500], Loss: 1.2547, Train Accuracy: 0.6395
# Validation Accuracy: 0.4664
# Current learning rate: [0.00125]
# Epoch [31/500], Loss: 1.2547, Train Accuracy: 0.6401
# Validation Accuracy: 0.4691
# Current learning rate: [0.00125]
# Epoch [32/500], Loss: 1.2427, Train Accuracy: 0.6432
# Validation Accuracy: 0.4700
# Current learning rate: [0.00125]
# Epoch [33/500], Loss: 1.2496, Train Accuracy: 0.6428
# Validation Accuracy: 0.4719
# Current learning rate: [0.00125]
# Epoch [34/500], Loss: 1.2338, Train Accuracy: 0.6425
# Validation Accuracy: 0.4685
# Current learning rate: [0.000625]
# Epoch [35/500], Loss: 1.2179, Train Accuracy: 0.6524
# Validation Accuracy: 0.4724
# Current learning rate: [0.000625]
# Epoch [36/500], Loss: 1.1974, Train Accuracy: 0.6556
# Validation Accuracy: 0.4681
# Current learning rate: [0.000625]
# Epoch [37/500], Loss: 1.1986, Train Accuracy: 0.6602
# Validation Accuracy: 0.4693
# Current learning rate: [0.000625]
# Epoch [38/500], Loss: 1.1943, Train Accuracy: 0.6600
# Validation Accuracy: 0.4696
# Current learning rate: [0.000625]
# Epoch [39/500], Loss: 1.1973, Train Accuracy: 0.6575
# Validation Accuracy: 0.4632
# Current learning rate: [0.000625]
# Epoch [40/500], Loss: 1.1888, Train Accuracy: 0.6548
# Validation Accuracy: 0.4646
# Current learning rate: [0.0003125]
# Epoch [41/500], Loss: 1.1780, Train Accuracy: 0.6649
# Validation Accuracy: 0.4659
# Current learning rate: [0.0003125]
# Epoch [42/500], Loss: 1.1677, Train Accuracy: 0.6635
# Validation Accuracy: 0.4688
# Current learning rate: [0.0003125]
# Early stopping at fold 1, epoch 42
#
# Fold 2/5
# Epoch [1/500], Loss: 1.9272, Train Accuracy: 0.4773
# Validation Accuracy: 0.4382
# Current learning rate: [0.01]
# Epoch [2/500], Loss: 1.7029, Train Accuracy: 0.5250
# Validation Accuracy: 0.4605
# Current learning rate: [0.01]
# Epoch [3/500], Loss: 1.6744, Train Accuracy: 0.5309
# Validation Accuracy: 0.4096
# Current learning rate: [0.01]
# Epoch [4/500], Loss: 1.6611, Train Accuracy: 0.5359
# Validation Accuracy: 0.4515
# Current learning rate: [0.01]
# Epoch [5/500], Loss: 1.6510, Train Accuracy: 0.5334
# Validation Accuracy: 0.4484
# Current learning rate: [0.01]
# Epoch [6/500], Loss: 1.6569, Train Accuracy: 0.5340
# Validation Accuracy: 0.4436
# Current learning rate: [0.01]
# Epoch [7/500], Loss: 1.6483, Train Accuracy: 0.5375
# Validation Accuracy: 0.4460
# Current learning rate: [0.01]
# Epoch [8/500], Loss: 1.6310, Train Accuracy: 0.5428
# Validation Accuracy: 0.4166
# Current learning rate: [0.005]
# Epoch [9/500], Loss: 1.5189, Train Accuracy: 0.5698
# Validation Accuracy: 0.4769
# Current learning rate: [0.005]
# Epoch [10/500], Loss: 1.4590, Train Accuracy: 0.5877
# Validation Accuracy: 0.4756
# Current learning rate: [0.005]
# Epoch [11/500], Loss: 1.4531, Train Accuracy: 0.5881
# Validation Accuracy: 0.4920
# Current learning rate: [0.005]
# New best model saved at fold 2, epoch 11 with val accuracy: 0.4920
# Epoch [12/500], Loss: 1.4486, Train Accuracy: 0.5901
# Validation Accuracy: 0.4788
# Current learning rate: [0.005]
# Epoch [13/500], Loss: 1.4434, Train Accuracy: 0.5869
# Validation Accuracy: 0.4748
# Current learning rate: [0.005]
# Epoch [14/500], Loss: 1.4378, Train Accuracy: 0.5904
# Validation Accuracy: 0.4744
# Current learning rate: [0.005]
# Epoch [15/500], Loss: 1.4359, Train Accuracy: 0.5897
# Validation Accuracy: 0.4669
# Current learning rate: [0.005]
# Epoch [16/500], Loss: 1.4241, Train Accuracy: 0.5923
# Validation Accuracy: 0.4721
# Current learning rate: [0.005]
# Epoch [17/500], Loss: 1.4218, Train Accuracy: 0.5946
# Validation Accuracy: 0.4677
# Current learning rate: [0.0025]
# Epoch [18/500], Loss: 1.3278, Train Accuracy: 0.6189
# Validation Accuracy: 0.4868
# Current learning rate: [0.0025]
# Epoch [19/500], Loss: 1.3023, Train Accuracy: 0.6263
# Validation Accuracy: 0.4901
# Current learning rate: [0.0025]
# Epoch [20/500], Loss: 1.2929, Train Accuracy: 0.6305
# Validation Accuracy: 0.4801
# Current learning rate: [0.0025]
# Epoch [21/500], Loss: 1.2889, Train Accuracy: 0.6296
# Validation Accuracy: 0.4880
# Current learning rate: [0.0025]
# Epoch [22/500], Loss: 1.2862, Train Accuracy: 0.6304
# Validation Accuracy: 0.4781
# Current learning rate: [0.0025]
# Epoch [23/500], Loss: 1.2811, Train Accuracy: 0.6316
# Validation Accuracy: 0.4771
# Current learning rate: [0.00125]
# Epoch [24/500], Loss: 1.2367, Train Accuracy: 0.6452
# Validation Accuracy: 0.4874
# Current learning rate: [0.00125]
# Epoch [25/500], Loss: 1.2196, Train Accuracy: 0.6509
# Validation Accuracy: 0.4955
# Current learning rate: [0.00125]
# New best model saved at fold 2, epoch 25 with val accuracy: 0.4955
# Epoch [26/500], Loss: 1.2100, Train Accuracy: 0.6541
# Validation Accuracy: 0.4864
# Current learning rate: [0.00125]
# Epoch [27/500], Loss: 1.2028, Train Accuracy: 0.6528
# Validation Accuracy: 0.4846
# Current learning rate: [0.00125]
# Epoch [28/500], Loss: 1.2061, Train Accuracy: 0.6542
# Validation Accuracy: 0.4850
# Current learning rate: [0.00125]
# Epoch [29/500], Loss: 1.2009, Train Accuracy: 0.6532
# Validation Accuracy: 0.4821
# Current learning rate: [0.00125]
# Epoch [30/500], Loss: 1.1987, Train Accuracy: 0.6552
# Validation Accuracy: 0.4845
# Current learning rate: [0.00125]
# Epoch [31/500], Loss: 1.1903, Train Accuracy: 0.6574
# Validation Accuracy: 0.4789
# Current learning rate: [0.000625]
# Epoch [32/500], Loss: 1.1637, Train Accuracy: 0.6653
# Validation Accuracy: 0.4845
# Current learning rate: [0.000625]
# Epoch [33/500], Loss: 1.1635, Train Accuracy: 0.6675
# Validation Accuracy: 0.4853
# Current learning rate: [0.000625]
# Epoch [34/500], Loss: 1.1519, Train Accuracy: 0.6712
# Validation Accuracy: 0.4860
# Current learning rate: [0.000625]
# Epoch [35/500], Loss: 1.1528, Train Accuracy: 0.6697
# Validation Accuracy: 0.4800
# Current learning rate: [0.000625]
# Epoch [36/500], Loss: 1.1558, Train Accuracy: 0.6667
# Validation Accuracy: 0.4830
# Current learning rate: [0.000625]
# Epoch [37/500], Loss: 1.1482, Train Accuracy: 0.6699
# Validation Accuracy: 0.4838
# Current learning rate: [0.0003125]
# Epoch [38/500], Loss: 1.1269, Train Accuracy: 0.6746
# Validation Accuracy: 0.4843
# Current learning rate: [0.0003125]
# Epoch [39/500], Loss: 1.1339, Train Accuracy: 0.6747
# Validation Accuracy: 0.4838
# Current learning rate: [0.0003125]
# Epoch [40/500], Loss: 1.1295, Train Accuracy: 0.6764
# Validation Accuracy: 0.4820
# Current learning rate: [0.0003125]
# Epoch [41/500], Loss: 1.1255, Train Accuracy: 0.6779
# Validation Accuracy: 0.4816
# Current learning rate: [0.0003125]
# Epoch [42/500], Loss: 1.1289, Train Accuracy: 0.6753
# Validation Accuracy: 0.4866
# Current learning rate: [0.0003125]
# Epoch [43/500], Loss: 1.1235, Train Accuracy: 0.6777
# Validation Accuracy: 0.4818
# Current learning rate: [0.00015625]
# Epoch [44/500], Loss: 1.1192, Train Accuracy: 0.6794
# Validation Accuracy: 0.4798
# Current learning rate: [0.00015625]
# Epoch [45/500], Loss: 1.1177, Train Accuracy: 0.6785
# Validation Accuracy: 0.4785
# Current learning rate: [0.00015625]
# Early stopping at fold 2, epoch 45
#
# Fold 3/5
# Epoch [1/500], Loss: 1.9136, Train Accuracy: 0.4795
# Validation Accuracy: 0.4153
# Current learning rate: [0.01]
# Epoch [2/500], Loss: 1.6795, Train Accuracy: 0.5285
# Validation Accuracy: 0.4764
# Current learning rate: [0.01]
# Epoch [3/500], Loss: 1.6419, Train Accuracy: 0.5382
# Validation Accuracy: 0.4361
# Current learning rate: [0.01]
# Epoch [4/500], Loss: 1.6313, Train Accuracy: 0.5399
# Validation Accuracy: 0.4645
# Current learning rate: [0.01]
# Epoch [5/500], Loss: 1.6039, Train Accuracy: 0.5468
# Validation Accuracy: 0.4577
# Current learning rate: [0.01]
# Epoch [6/500], Loss: 1.6161, Train Accuracy: 0.5434
# Validation Accuracy: 0.4576
# Current learning rate: [0.01]
# Epoch [7/500], Loss: 1.6099, Train Accuracy: 0.5426
# Validation Accuracy: 0.4586
# Current learning rate: [0.01]
# Epoch [8/500], Loss: 1.6009, Train Accuracy: 0.5445
# Validation Accuracy: 0.4361
# Current learning rate: [0.005]
# Epoch [9/500], Loss: 1.4755, Train Accuracy: 0.5813
# Validation Accuracy: 0.4896
# Current learning rate: [0.005]
# Epoch [10/500], Loss: 1.4055, Train Accuracy: 0.6007
# Validation Accuracy: 0.4953
# Current learning rate: [0.005]
# Epoch [11/500], Loss: 1.3912, Train Accuracy: 0.5988
# Validation Accuracy: 0.4930
# Current learning rate: [0.005]
# Epoch [12/500], Loss: 1.3943, Train Accuracy: 0.6004
# Validation Accuracy: 0.4925
# Current learning rate: [0.005]
# Epoch [13/500], Loss: 1.3927, Train Accuracy: 0.6013
# Validation Accuracy: 0.4969
# Current learning rate: [0.005]
# New best model saved at fold 3, epoch 13 with val accuracy: 0.4969
# Epoch [14/500], Loss: 1.3894, Train Accuracy: 0.6018
# Validation Accuracy: 0.4879
# Current learning rate: [0.005]
# Epoch [15/500], Loss: 1.3833, Train Accuracy: 0.6008
# Validation Accuracy: 0.4919
# Current learning rate: [0.005]
# Epoch [16/500], Loss: 1.3854, Train Accuracy: 0.6026
# Validation Accuracy: 0.4758
# Current learning rate: [0.005]
# Epoch [17/500], Loss: 1.3844, Train Accuracy: 0.6008
# Validation Accuracy: 0.4779
# Current learning rate: [0.005]
# Epoch [18/500], Loss: 1.3795, Train Accuracy: 0.6016
# Validation Accuracy: 0.4980
# Current learning rate: [0.005]
# New best model saved at fold 3, epoch 18 with val accuracy: 0.4980
# Epoch [19/500], Loss: 1.3648, Train Accuracy: 0.6067
# Validation Accuracy: 0.4698
# Current learning rate: [0.005]
# Epoch [20/500], Loss: 1.3687, Train Accuracy: 0.6052
# Validation Accuracy: 0.4715
# Current learning rate: [0.005]
# Epoch [21/500], Loss: 1.3623, Train Accuracy: 0.6086
# Validation Accuracy: 0.4637
# Current learning rate: [0.005]
# Epoch [22/500], Loss: 1.3675, Train Accuracy: 0.6064
# Validation Accuracy: 0.4640
# Current learning rate: [0.005]
# Epoch [23/500], Loss: 1.3501, Train Accuracy: 0.6106
# Validation Accuracy: 0.4845
# Current learning rate: [0.005]
# Epoch [24/500], Loss: 1.3409, Train Accuracy: 0.6133
# Validation Accuracy: 0.4626
# Current learning rate: [0.0025]
# Epoch [25/500], Loss: 1.2686, Train Accuracy: 0.6332
# Validation Accuracy: 0.4904
# Current learning rate: [0.0025]
# Epoch [26/500], Loss: 1.2307, Train Accuracy: 0.6441
# Validation Accuracy: 0.4949
# Current learning rate: [0.0025]
# Epoch [27/500], Loss: 1.2170, Train Accuracy: 0.6471
# Validation Accuracy: 0.4986
# Current learning rate: [0.0025]
# New best model saved at fold 3, epoch 27 with val accuracy: 0.4986
# Epoch [28/500], Loss: 1.2033, Train Accuracy: 0.6519
# Validation Accuracy: 0.4884
# Current learning rate: [0.0025]
# Epoch [29/500], Loss: 1.1978, Train Accuracy: 0.6513
# Validation Accuracy: 0.4820
# Current learning rate: [0.0025]
# Epoch [30/500], Loss: 1.1972, Train Accuracy: 0.6528
# Validation Accuracy: 0.4845
# Current learning rate: [0.0025]
# Epoch [31/500], Loss: 1.2057, Train Accuracy: 0.6500
# Validation Accuracy: 0.4899
# Current learning rate: [0.0025]
# Epoch [32/500], Loss: 1.1972, Train Accuracy: 0.6519
# Validation Accuracy: 0.4830
# Current learning rate: [0.0025]
# Epoch [33/500], Loss: 1.2063, Train Accuracy: 0.6505
# Validation Accuracy: 0.4906
# Current learning rate: [0.00125]
# Epoch [34/500], Loss: 1.1354, Train Accuracy: 0.6677
# Validation Accuracy: 0.4948
# Current learning rate: [0.00125]
# Epoch [35/500], Loss: 1.1211, Train Accuracy: 0.6746
# Validation Accuracy: 0.4944
# Current learning rate: [0.00125]
# Epoch [36/500], Loss: 1.1103, Train Accuracy: 0.6782
# Validation Accuracy: 0.4939
# Current learning rate: [0.00125]
# Epoch [37/500], Loss: 1.1110, Train Accuracy: 0.6761
# Validation Accuracy: 0.4889
# Current learning rate: [0.00125]
# Epoch [38/500], Loss: 1.1022, Train Accuracy: 0.6798
# Validation Accuracy: 0.4918
# Current learning rate: [0.00125]
# Epoch [39/500], Loss: 1.1038, Train Accuracy: 0.6789
# Validation Accuracy: 0.4885
# Current learning rate: [0.000625]
# Epoch [40/500], Loss: 1.0766, Train Accuracy: 0.6885
# Validation Accuracy: 0.4944
# Current learning rate: [0.000625]
# Epoch [41/500], Loss: 1.0609, Train Accuracy: 0.6925
# Validation Accuracy: 0.4945
# Current learning rate: [0.000625]
# Epoch [42/500], Loss: 1.0589, Train Accuracy: 0.6936
# Validation Accuracy: 0.4954
# Current learning rate: [0.000625]
# Epoch [43/500], Loss: 1.0576, Train Accuracy: 0.6912
# Validation Accuracy: 0.4938
# Current learning rate: [0.000625]
# Epoch [44/500], Loss: 1.0523, Train Accuracy: 0.6940
# Validation Accuracy: 0.4959
# Current learning rate: [0.000625]
# Epoch [45/500], Loss: 1.0589, Train Accuracy: 0.6943
# Validation Accuracy: 0.4881
# Current learning rate: [0.0003125]
# Epoch [46/500], Loss: 1.0469, Train Accuracy: 0.6970
# Validation Accuracy: 0.4921
# Current learning rate: [0.0003125]
# Epoch [47/500], Loss: 1.0381, Train Accuracy: 0.7017
# Validation Accuracy: 0.4969
# Current learning rate: [0.0003125]
# Early stopping at fold 3, epoch 47
#
# Fold 4/5
# Epoch [1/500], Loss: 1.9205, Train Accuracy: 0.4863
# Validation Accuracy: 0.4233
# Current learning rate: [0.01]
# Epoch [2/500], Loss: 1.6304, Train Accuracy: 0.5385
# Validation Accuracy: 0.4649
# Current learning rate: [0.01]
# Epoch [3/500], Loss: 1.5735, Train Accuracy: 0.5512
# Validation Accuracy: 0.4736
# Current learning rate: [0.01]
# Epoch [4/500], Loss: 1.5663, Train Accuracy: 0.5525
# Validation Accuracy: 0.4620
# Current learning rate: [0.01]
# Epoch [5/500], Loss: 1.5595, Train Accuracy: 0.5567
# Validation Accuracy: 0.4773
# Current learning rate: [0.01]
# Epoch [6/500], Loss: 1.5630, Train Accuracy: 0.5574
# Validation Accuracy: 0.4746
# Current learning rate: [0.01]
# Epoch [7/500], Loss: 1.5500, Train Accuracy: 0.5554
# Validation Accuracy: 0.4675
# Current learning rate: [0.01]
# Epoch [8/500], Loss: 1.5421, Train Accuracy: 0.5587
# Validation Accuracy: 0.4585
# Current learning rate: [0.01]
# Epoch [9/500], Loss: 1.5458, Train Accuracy: 0.5568
# Validation Accuracy: 0.4536
# Current learning rate: [0.01]
# Epoch [10/500], Loss: 1.5371, Train Accuracy: 0.5615
# Validation Accuracy: 0.4535
# Current learning rate: [0.01]
# Epoch [11/500], Loss: 1.5398, Train Accuracy: 0.5595
# Validation Accuracy: 0.4437
# Current learning rate: [0.005]
# Epoch [12/500], Loss: 1.3952, Train Accuracy: 0.5996
# Validation Accuracy: 0.5089
# Current learning rate: [0.005]
# New best model saved at fold 4, epoch 12 with val accuracy: 0.5089
# Epoch [13/500], Loss: 1.3293, Train Accuracy: 0.6165
# Validation Accuracy: 0.4994
# Current learning rate: [0.005]
# Epoch [14/500], Loss: 1.3219, Train Accuracy: 0.6178
# Validation Accuracy: 0.5005
# Current learning rate: [0.005]
# Epoch [15/500], Loss: 1.3238, Train Accuracy: 0.6189
# Validation Accuracy: 0.4943
# Current learning rate: [0.005]
# Epoch [16/500], Loss: 1.3152, Train Accuracy: 0.6211
# Validation Accuracy: 0.4854
# Current learning rate: [0.005]
# Epoch [17/500], Loss: 1.3213, Train Accuracy: 0.6186
# Validation Accuracy: 0.4891
# Current learning rate: [0.005]
# Epoch [18/500], Loss: 1.3063, Train Accuracy: 0.6189
# Validation Accuracy: 0.4885
# Current learning rate: [0.0025]
# Epoch [19/500], Loss: 1.2184, Train Accuracy: 0.6465
# Validation Accuracy: 0.5148
# Current learning rate: [0.0025]
# New best model saved at fold 4, epoch 19 with val accuracy: 0.5148
# Epoch [20/500], Loss: 1.1797, Train Accuracy: 0.6619
# Validation Accuracy: 0.5104
# Current learning rate: [0.0025]
# Epoch [21/500], Loss: 1.1774, Train Accuracy: 0.6590
# Validation Accuracy: 0.5044
# Current learning rate: [0.0025]
# Epoch [22/500], Loss: 1.1672, Train Accuracy: 0.6624
# Validation Accuracy: 0.5020
# Current learning rate: [0.0025]
# Epoch [23/500], Loss: 1.1671, Train Accuracy: 0.6620
# Validation Accuracy: 0.4953
# Current learning rate: [0.0025]
# Epoch [24/500], Loss: 1.1668, Train Accuracy: 0.6614
# Validation Accuracy: 0.4983
# Current learning rate: [0.0025]
# Epoch [25/500], Loss: 1.1612, Train Accuracy: 0.6645
# Validation Accuracy: 0.4981
# Current learning rate: [0.00125]
# Epoch [26/500], Loss: 1.1014, Train Accuracy: 0.6822
# Validation Accuracy: 0.5065
# Current learning rate: [0.00125]
# Epoch [27/500], Loss: 1.0841, Train Accuracy: 0.6885
# Validation Accuracy: 0.5016
# Current learning rate: [0.00125]
# Epoch [28/500], Loss: 1.0714, Train Accuracy: 0.6887
# Validation Accuracy: 0.5115
# Current learning rate: [0.00125]
# Epoch [29/500], Loss: 1.0770, Train Accuracy: 0.6892
# Validation Accuracy: 0.5041
# Current learning rate: [0.00125]
# Epoch [30/500], Loss: 1.0703, Train Accuracy: 0.6914
# Validation Accuracy: 0.5041
# Current learning rate: [0.00125]
# Epoch [31/500], Loss: 1.0609, Train Accuracy: 0.6914
# Validation Accuracy: 0.5054
# Current learning rate: [0.000625]
# Epoch [32/500], Loss: 1.0404, Train Accuracy: 0.7006
# Validation Accuracy: 0.5098
# Current learning rate: [0.000625]
# Epoch [33/500], Loss: 1.0308, Train Accuracy: 0.7029
# Validation Accuracy: 0.5070
# Current learning rate: [0.000625]
# Epoch [34/500], Loss: 1.0236, Train Accuracy: 0.7044
# Validation Accuracy: 0.5059
# Current learning rate: [0.000625]
# Epoch [35/500], Loss: 1.0176, Train Accuracy: 0.7047
# Validation Accuracy: 0.5036
# Current learning rate: [0.000625]
# Epoch [36/500], Loss: 1.0221, Train Accuracy: 0.7035
# Validation Accuracy: 0.5031
# Current learning rate: [0.000625]
# Epoch [37/500], Loss: 1.0133, Train Accuracy: 0.7074
# Validation Accuracy: 0.5024
# Current learning rate: [0.0003125]
# Epoch [38/500], Loss: 1.0029, Train Accuracy: 0.7108
# Validation Accuracy: 0.5012
# Current learning rate: [0.0003125]
# Epoch [39/500], Loss: 0.9905, Train Accuracy: 0.7135
# Validation Accuracy: 0.5031
# Current learning rate: [0.0003125]
# Early stopping at fold 4, epoch 39
#
# Fold 5/5
# Epoch [1/500], Loss: 1.8438, Train Accuracy: 0.4957
# Validation Accuracy: 0.4061
# Current learning rate: [0.01]
# Epoch [2/500], Loss: 1.5907, Train Accuracy: 0.5479
# Validation Accuracy: 0.4971
# Current learning rate: [0.01]
# Epoch [3/500], Loss: 1.5360, Train Accuracy: 0.5625
# Validation Accuracy: 0.4979
# Current learning rate: [0.01]
# Epoch [4/500], Loss: 1.5305, Train Accuracy: 0.5628
# Validation Accuracy: 0.4625
# Current learning rate: [0.01]
# Epoch [5/500], Loss: 1.5172, Train Accuracy: 0.5649
# Validation Accuracy: 0.4853
# Current learning rate: [0.01]
# Epoch [6/500], Loss: 1.5260, Train Accuracy: 0.5668
# Validation Accuracy: 0.4871
# Current learning rate: [0.01]
# Epoch [7/500], Loss: 1.5262, Train Accuracy: 0.5620
# Validation Accuracy: 0.4875
# Current learning rate: [0.01]
# Epoch [8/500], Loss: 1.5101, Train Accuracy: 0.5685
# Validation Accuracy: 0.4535
# Current learning rate: [0.01]
# Epoch [9/500], Loss: 1.5101, Train Accuracy: 0.5671
# Validation Accuracy: 0.4586
# Current learning rate: [0.005]
# Epoch [10/500], Loss: 1.3736, Train Accuracy: 0.6045
# Validation Accuracy: 0.5022
# Current learning rate: [0.005]
# Epoch [11/500], Loss: 1.3080, Train Accuracy: 0.6250
# Validation Accuracy: 0.5089
# Current learning rate: [0.005]
# Epoch [12/500], Loss: 1.2892, Train Accuracy: 0.6280
# Validation Accuracy: 0.5016
# Current learning rate: [0.005]
# Epoch [13/500], Loss: 1.2762, Train Accuracy: 0.6278
# Validation Accuracy: 0.5035
# Current learning rate: [0.005]
# Epoch [14/500], Loss: 1.2772, Train Accuracy: 0.6265
# Validation Accuracy: 0.4879
# Current learning rate: [0.005]
# Epoch [15/500], Loss: 1.2866, Train Accuracy: 0.6273
# Validation Accuracy: 0.4996
# Current learning rate: [0.005]
# Epoch [16/500], Loss: 1.2795, Train Accuracy: 0.6290
# Validation Accuracy: 0.4841
# Current learning rate: [0.005]
# Epoch [17/500], Loss: 1.2771, Train Accuracy: 0.6269
# Validation Accuracy: 0.4826
# Current learning rate: [0.0025]
# Epoch [18/500], Loss: 1.1709, Train Accuracy: 0.6585
# Validation Accuracy: 0.5210
# Current learning rate: [0.0025]
# New best model saved at fold 5, epoch 18 with val accuracy: 0.5210
# Epoch [19/500], Loss: 1.1368, Train Accuracy: 0.6697
# Validation Accuracy: 0.5168
# Current learning rate: [0.0025]
# Epoch [20/500], Loss: 1.1300, Train Accuracy: 0.6681
# Validation Accuracy: 0.5174
# Current learning rate: [0.0025]
# Epoch [21/500], Loss: 1.1142, Train Accuracy: 0.6748
# Validation Accuracy: 0.5080
# Current learning rate: [0.0025]
# Epoch [22/500], Loss: 1.1158, Train Accuracy: 0.6769
# Validation Accuracy: 0.5109
# Current learning rate: [0.0025]
# Epoch [23/500], Loss: 1.1085, Train Accuracy: 0.6773
# Validation Accuracy: 0.5101
# Current learning rate: [0.0025]
# Epoch [24/500], Loss: 1.1025, Train Accuracy: 0.6770
# Validation Accuracy: 0.5114
# Current learning rate: [0.00125]
# Epoch [25/500], Loss: 1.0464, Train Accuracy: 0.6931
# Validation Accuracy: 0.5121
# Current learning rate: [0.00125]
# Epoch [26/500], Loss: 1.0295, Train Accuracy: 0.7015
# Validation Accuracy: 0.5166
# Current learning rate: [0.00125]
# Epoch [27/500], Loss: 1.0304, Train Accuracy: 0.7007
# Validation Accuracy: 0.5176
# Current learning rate: [0.00125]
# Epoch [28/500], Loss: 1.0176, Train Accuracy: 0.7037
# Validation Accuracy: 0.5094
# Current learning rate: [0.00125]
# Epoch [29/500], Loss: 1.0138, Train Accuracy: 0.7046
# Validation Accuracy: 0.5131
# Current learning rate: [0.00125]
# Epoch [30/500], Loss: 1.0110, Train Accuracy: 0.7040
# Validation Accuracy: 0.5099
# Current learning rate: [0.000625]
# Epoch [31/500], Loss: 0.9767, Train Accuracy: 0.7175
# Validation Accuracy: 0.5150
# Current learning rate: [0.000625]
# Epoch [32/500], Loss: 0.9802, Train Accuracy: 0.7186
# Validation Accuracy: 0.5130
# Current learning rate: [0.000625]
# Epoch [33/500], Loss: 0.9746, Train Accuracy: 0.7193
# Validation Accuracy: 0.5099
# Current learning rate: [0.000625]
# Epoch [34/500], Loss: 0.9654, Train Accuracy: 0.7223
# Validation Accuracy: 0.5096
# Current learning rate: [0.000625]
# Epoch [35/500], Loss: 0.9662, Train Accuracy: 0.7226
# Validation Accuracy: 0.5148
# Current learning rate: [0.000625]
# Epoch [36/500], Loss: 0.9580, Train Accuracy: 0.7227
# Validation Accuracy: 0.5131
# Current learning rate: [0.0003125]
# Epoch [37/500], Loss: 0.9505, Train Accuracy: 0.7255
# Validation Accuracy: 0.5114
# Current learning rate: [0.0003125]
# Epoch [38/500], Loss: 0.9430, Train Accuracy: 0.7281
# Validation Accuracy: 0.5115
# Current learning rate: [0.0003125]
# Early stopping at fold 5, epoch 38
# Best model saved with validation accuracy: 0.5210

# %%
import torch
import torch.nn as nn
import torch.optim as optim
import numpy as np
import pandas as pd
from tqdm import tqdm
from sklearn.model_selection import KFold
from torch.utils.data import DataLoader, Subset
import random

# Hyperparameters
num_epochs = 500  # 최대 Epoch 수
learning_rate = 0.01  # 초기 학습률
weight_decay = 1e-4  # weight decay (L2 정규화)
batch_size = 1024

# 손실 함수 및 옵티마이저
criterion = nn.CrossEntropyLoss()

# K-Fold Cross Validation
kf = KFold(n_splits=5, shuffle=True, random_state=42)

# 최상의 모델 가중치를 저장하기 위한 변수
best_val_accuracy = 0
best_model_state = None

# CutMix 함수
def cutmix(data, targets, alpha=1.0):
    if alpha > 0:
        beta = np.random.beta(alpha, alpha)
    else:
        beta = 1.0

    batch_size = data.size()[0]
    indices = torch.randperm(batch_size)

    # CutMix ratio
    lam = beta
    cutmix_data = data.clone()

    for i in range(batch_size):
        cut_x1 = random.randint(0, data.size(2) - 1)
        cut_y1 = random.randint(0, data.size(3) - 1)
        cut_x2 = random.randint(0, data.size(2) - 1)
        cut_y2 = random.randint(0, data.size(3) - 1)

        # Ensure the cut is within bounds
        x1 = min(cut_x1, cut_x2)
        x2 = max(cut_x1, cut_x2)
        y1 = min(cut_y1, cut_y2)
        y2 = max(cut_y1, cut_y2)

        cutmix_data[i, :, y1:y2, x1:x2] = data[indices[i], :, y1:y2, x1:x2]

    # Label interpolation
    targets_a = targets
    targets_b = targets[indices]
    targets_mixed = (targets_a, targets_b, lam)

    return cutmix_data, targets_mixed

# K-Fold 학습 루프
for fold, (train_idx, val_idx) in enumerate(kf.split(train_dataset)):
    print(f'\nFold {fold + 1}/{kf.n_splits}')

    # Train/Validation Subset 생성
    train_subset = Subset(train_dataset, train_idx)
    val_subset = Subset(train_dataset, val_idx)

    # DataLoader 설정
    train_loader = DataLoader(train_subset, batch_size=batch_size, shuffle=True, num_workers=4)
    val_loader = DataLoader(val_subset, batch_size=batch_size, shuffle=False, num_workers=4)

    # 모델 초기화
    model.cuda()  # GPU 사용

    # 옵티마이저 및 스케줄러 설정
    optimizer = optim.Adam(model.parameters(), lr=learning_rate, weight_decay=weight_decay)
    scheduler = optim.lr_scheduler.ReduceLROnPlateau(optimizer, mode='max', factor=0.5, patience=5, verbose=True)

    # Early Stopping 기준
    early_stopping_patience = 20
    early_stopping_counter = 0

    # - 모델 학습 및 검증을 수행하는 메인 루프
    for epoch in range(num_epochs):
        model.train()
        total_loss = 0
        correct = 0

        # 학습 루프
        for batch_features, batch_labels in train_loader:
            batch_features, batch_labels = batch_features.cuda(), batch_labels.cuda()

            # CutMix 적용
            batch_features, targets_mixed = cutmix(batch_features, batch_labels)

            optimizer.zero_grad()
            outputs = model(batch_features)

            # CutMix에 따른 손실 계산
            loss = criterion(outputs, targets_mixed[0]) * (1 - targets_mixed[2]) + \
                   criterion(outputs, targets_mixed[1]) * targets_mixed[2]

            loss.backward()
            optimizer.step()

            total_loss += loss.item()
            _, predicted = torch.max(outputs, 1)
            correct += (predicted == targets_mixed[0]).sum().item()

        # 학습 결과 출력
        average_loss = total_loss / len(train_loader)
        train_accuracy = correct / len(train_subset)
        print(f'Epoch [{epoch + 1}/{num_epochs}], Loss: {average_loss:.4f}, Train Accuracy: {train_accuracy:.4f}')

        # 검증 루프
        model.eval()
        val_correct = 0
        with torch.no_grad():
            for val_features, val_labels in val_loader:
                val_features, val_labels = val_features.cuda(), val_labels.cuda()
                val_outputs = model(val_features)
                _, val_predicted = torch.max(val_outputs, 1)
                val_correct += (val_predicted == val_labels).sum().item()

        # 검증 정확도 출력
        val_accuracy = val_correct / len(val_subset)
        print(f'Validation Accuracy: {val_accuracy:.4f}')

        # 스케줄러를 통해 학습률 조정
        scheduler.step(val_accuracy)
        print("Current learning rate:", scheduler.get_last_lr())

        # Early Stopping 체크
        if val_accuracy > best_val_accuracy:
            best_val_accuracy = val_accuracy
            early_stopping_counter = 0
            best_model_state = model.state_dict()  # 현재 모델의 가중치 저장
            print(f"New best model saved at fold {fold + 1}, epoch {epoch + 1} with val accuracy: {val_accuracy:.4f}")
        else:
            early_stopping_counter += 1
            if early_stopping_counter >= early_stopping_patience:
                print(f"Early stopping at fold {fold + 1}, epoch {epoch + 1}")
                break

# 최상의 모델 가중치 저장
torch.save(best_model_state, 'best_model.pth')
print(f"Best model saved with validation accuracy: {best_val_accuracy:.4f}")
# Out:
# Fold 1/5
# Epoch [1/500], Loss: 3.5881, Train Accuracy: 0.4326
# Validation Accuracy: 0.4760
# Current learning rate: [0.01]
# New best model saved at fold 1, epoch 1 with val accuracy: 0.4760
# Epoch [2/500], Loss: 3.4114, Train Accuracy: 0.4720
# Validation Accuracy: 0.5014
# Current learning rate: [0.01]
# New best model saved at fold 1, epoch 2 with val accuracy: 0.5014
# Epoch [3/500], Loss: 3.5714, Train Accuracy: 0.4670
# Validation Accuracy: 0.5004
# Current learning rate: [0.01]
# Epoch [4/500], Loss: 3.3444, Train Accuracy: 0.4786
# Validation Accuracy: 0.4576
# Current learning rate: [0.01]
# Epoch [5/500], Loss: 3.6972, Train Accuracy: 0.4531
# Validation Accuracy: 0.4230
# Current learning rate: [0.01]
# Epoch [6/500], Loss: 3.4549, Train Accuracy: 0.4694
# Validation Accuracy: 0.3635
# Current learning rate: [0.01]
# Epoch [7/500], Loss: 3.6100, Train Accuracy: 0.4699
# Validation Accuracy: 0.4419
# Current learning rate: [0.01]
# Epoch [8/500], Loss: 3.7055, Train Accuracy: 0.4573
# Validation Accuracy: 0.4035
# Current learning rate: [0.005]
# Epoch [9/500], Loss: 3.5841, Train Accuracy: 0.4812
# Validation Accuracy: 0.5394
# Current learning rate: [0.005]
# New best model saved at fold 1, epoch 9 with val accuracy: 0.5394
# Epoch [10/500], Loss: 3.5794, Train Accuracy: 0.4946
# Validation Accuracy: 0.5285
# Current learning rate: [0.005]
# Epoch [11/500], Loss: 3.4596, Train Accuracy: 0.4956
# Validation Accuracy: 0.5272
# Current learning rate: [0.005]
# Epoch [12/500], Loss: 3.4026, Train Accuracy: 0.5131
# Validation Accuracy: 0.5443
# Current learning rate: [0.005]
# New best model saved at fold 1, epoch 12 with val accuracy: 0.5443
# Epoch [13/500], Loss: 3.5995, Train Accuracy: 0.4982
# Validation Accuracy: 0.5510
# Current learning rate: [0.005]
# New best model saved at fold 1, epoch 13 with val accuracy: 0.5510
# Epoch [14/500], Loss: 3.6745, Train Accuracy: 0.4862
# Validation Accuracy: 0.5060
# Current learning rate: [0.005]
# Epoch [15/500], Loss: 3.5027, Train Accuracy: 0.4820
# Validation Accuracy: 0.5289
# Current learning rate: [0.005]
# Epoch [16/500], Loss: 3.4491, Train Accuracy: 0.5107
# Validation Accuracy: 0.5264
# Current learning rate: [0.005]
# Epoch [17/500], Loss: 3.3238, Train Accuracy: 0.5082
# Validation Accuracy: 0.5510
# Current learning rate: [0.005]
# Epoch [18/500], Loss: 3.3724, Train Accuracy: 0.5176
# Validation Accuracy: 0.5489
# Current learning rate: [0.005]
# Epoch [19/500], Loss: 3.4511, Train Accuracy: 0.5138
# Validation Accuracy: 0.5246
# Current learning rate: [0.0025]
# Epoch [20/500], Loss: 3.6086, Train Accuracy: 0.5201
# Validation Accuracy: 0.5667
# Current learning rate: [0.0025]
# New best model saved at fold 1, epoch 20 with val accuracy: 0.5667
# Epoch [21/500], Loss: 3.1933, Train Accuracy: 0.5301
# Validation Accuracy: 0.5827
# Current learning rate: [0.0025]
# New best model saved at fold 1, epoch 21 with val accuracy: 0.5827
# Epoch [22/500], Loss: 3.5289, Train Accuracy: 0.5400
# Validation Accuracy: 0.5779
# Current learning rate: [0.0025]
# Epoch [23/500], Loss: 3.2742, Train Accuracy: 0.5470
# Validation Accuracy: 0.5806
# Current learning rate: [0.0025]
# Epoch [24/500], Loss: 3.5320, Train Accuracy: 0.5427
# Validation Accuracy: 0.5743
# Current learning rate: [0.0025]
# Epoch [25/500], Loss: 3.3260, Train Accuracy: 0.5480
# Validation Accuracy: 0.5575
# Current learning rate: [0.0025]
# Epoch [26/500], Loss: 3.3779, Train Accuracy: 0.5444
# Validation Accuracy: 0.5803
# Current learning rate: [0.0025]
# Epoch [27/500], Loss: 3.2290, Train Accuracy: 0.5528
# Validation Accuracy: 0.5901
# Current learning rate: [0.0025]
# New best model saved at fold 1, epoch 27 with val accuracy: 0.5901
# Epoch [28/500], Loss: 3.4109, Train Accuracy: 0.5577
# Validation Accuracy: 0.5674
# Current learning rate: [0.0025]
# Epoch [29/500], Loss: 3.3806, Train Accuracy: 0.5381
# Validation Accuracy: 0.5839
# Current learning rate: [0.0025]
# Epoch [30/500], Loss: 3.3018, Train Accuracy: 0.5693
# Validation Accuracy: 0.5801
# Current learning rate: [0.0025]
# Epoch [31/500], Loss: 3.2132, Train Accuracy: 0.5588
# Validation Accuracy: 0.5836
# Current learning rate: [0.0025]
# Epoch [32/500], Loss: 3.3239, Train Accuracy: 0.5598
# Validation Accuracy: 0.5790
# Current learning rate: [0.0025]
# Epoch [33/500], Loss: 3.5833, Train Accuracy: 0.5575
# Validation Accuracy: 0.5783
# Current learning rate: [0.00125]
# Epoch [34/500], Loss: 3.2925, Train Accuracy: 0.5664
# Validation Accuracy: 0.6034
# Current learning rate: [0.00125]
# New best model saved at fold 1, epoch 34 with val accuracy: 0.6034
# Epoch [35/500], Loss: 3.3984, Train Accuracy: 0.5761
# Validation Accuracy: 0.6048
# Current learning rate: [0.00125]
# New best model saved at fold 1, epoch 35 with val accuracy: 0.6048
# Epoch [36/500], Loss: 3.2677, Train Accuracy: 0.5737
# Validation Accuracy: 0.5998
# Current learning rate: [0.00125]
# Epoch [37/500], Loss: 3.3242, Train Accuracy: 0.5827
# Validation Accuracy: 0.6089
# Current learning rate: [0.00125]
# New best model saved at fold 1, epoch 37 with val accuracy: 0.6089
# Epoch [38/500], Loss: 3.2189, Train Accuracy: 0.5837
# Validation Accuracy: 0.6114
# Current learning rate: [0.00125]
# New best model saved at fold 1, epoch 38 with val accuracy: 0.6114
# Epoch [39/500], Loss: 3.3001, Train Accuracy: 0.5855
# Validation Accuracy: 0.6009
# Current learning rate: [0.00125]
# Epoch [40/500], Loss: 3.4031, Train Accuracy: 0.5792
# Validation Accuracy: 0.5976
# Current learning rate: [0.00125]
# Epoch [41/500], Loss: 3.2116, Train Accuracy: 0.5846
# Validation Accuracy: 0.5999
# Current learning rate: [0.00125]
# Epoch [42/500], Loss: 3.1953, Train Accuracy: 0.5914
# Validation Accuracy: 0.6088
# Current learning rate: [0.00125]
# Epoch [43/500], Loss: 3.3129, Train Accuracy: 0.5992
# Validation Accuracy: 0.6028
# Current learning rate: [0.00125]
# Epoch [44/500], Loss: 3.0968, Train Accuracy: 0.5954
# Validation Accuracy: 0.6138
# Current learning rate: [0.00125]
# New best model saved at fold 1, epoch 44 with val accuracy: 0.6138
# Epoch [45/500], Loss: 3.3994, Train Accuracy: 0.5905
# Validation Accuracy: 0.6049
# Current learning rate: [0.00125]
# Epoch [46/500], Loss: 3.2883, Train Accuracy: 0.5834
# Validation Accuracy: 0.6002
# Current learning rate: [0.00125]
# Epoch [47/500], Loss: 3.1110, Train Accuracy: 0.6021
# Validation Accuracy: 0.6061
# Current learning rate: [0.00125]
# Epoch [48/500], Loss: 3.2438, Train Accuracy: 0.6045
# Validation Accuracy: 0.5982
# Current learning rate: [0.00125]
# Epoch [49/500], Loss: 3.4160, Train Accuracy: 0.5918
# Validation Accuracy: 0.6021
# Current learning rate: [0.00125]
# Epoch [50/500], Loss: 3.2770, Train Accuracy: 0.5933
# Validation Accuracy: 0.6055
# Current learning rate: [0.000625]
# Epoch [51/500], Loss: 3.2015, Train Accuracy: 0.5968
# Validation Accuracy: 0.6178
# Current learning rate: [0.000625]
# New best model saved at fold 1, epoch 51 with val accuracy: 0.6178
# Epoch [52/500], Loss: 3.1955, Train Accuracy: 0.6139
# Validation Accuracy: 0.6105
# Current learning rate: [0.000625]
# Epoch [53/500], Loss: 3.0726, Train Accuracy: 0.6131
# Validation Accuracy: 0.6159
# Current learning rate: [0.000625]
# Epoch [54/500], Loss: 3.0630, Train Accuracy: 0.6207
# Validation Accuracy: 0.6196
# Current learning rate: [0.000625]
# New best model saved at fold 1, epoch 54 with val accuracy: 0.6196
# Epoch [55/500], Loss: 3.3088, Train Accuracy: 0.6192
# Validation Accuracy: 0.6159
# Current learning rate: [0.000625]
# Epoch [56/500], Loss: 3.4207, Train Accuracy: 0.6125
# Validation Accuracy: 0.6138
# Current learning rate: [0.000625]
# Epoch [57/500], Loss: 3.0585, Train Accuracy: 0.6093
# Validation Accuracy: 0.6159
# Current learning rate: [0.000625]
# Epoch [58/500], Loss: 3.1610, Train Accuracy: 0.6205
# Validation Accuracy: 0.6145
# Current learning rate: [0.000625]
# Epoch [59/500], Loss: 3.2228, Train Accuracy: 0.6189
# Validation Accuracy: 0.6198
# Current learning rate: [0.000625]
# New best model saved at fold 1, epoch 59 with val accuracy: 0.6198
# Epoch [60/500], Loss: 3.3523, Train Accuracy: 0.6136
# Validation Accuracy: 0.6112
# Current learning rate: [0.000625]
# Epoch [61/500], Loss: 3.0771, Train Accuracy: 0.6225
# Validation Accuracy: 0.6162
# Current learning rate: [0.000625]
# Epoch [62/500], Loss: 3.2155, Train Accuracy: 0.6193
# Validation Accuracy: 0.6184
# Current learning rate: [0.000625]
# Epoch [63/500], Loss: 3.2762, Train Accuracy: 0.6238
# Validation Accuracy: 0.6198
# Current learning rate: [0.000625]
# Epoch [64/500], Loss: 3.2427, Train Accuracy: 0.6175
# Validation Accuracy: 0.6215
# Current learning rate: [0.000625]
# New best model saved at fold 1, epoch 64 with val accuracy: 0.6215
# Epoch [65/500], Loss: 3.2148, Train Accuracy: 0.6222
# Validation Accuracy: 0.6158
# Current learning rate: [0.000625]
# Epoch [66/500], Loss: 3.0643, Train Accuracy: 0.6236
# Validation Accuracy: 0.6188
# Current learning rate: [0.000625]
# Epoch [67/500], Loss: 3.3401, Train Accuracy: 0.6275
# Validation Accuracy: 0.6059
# Current learning rate: [0.000625]
# Epoch [68/500], Loss: 3.4407, Train Accuracy: 0.6097
# Validation Accuracy: 0.6149
# Current learning rate: [0.000625]
# Epoch [69/500], Loss: 3.1966, Train Accuracy: 0.6152
# Validation Accuracy: 0.6159
# Current learning rate: [0.000625]
# Epoch [70/500], Loss: 3.3596, Train Accuracy: 0.6172
# Validation Accuracy: 0.6159
# Current learning rate: [0.0003125]
# Epoch [71/500], Loss: 3.3360, Train Accuracy: 0.6126
# Validation Accuracy: 0.6200
# Current learning rate: [0.0003125]
# Epoch [72/500], Loss: 3.0955, Train Accuracy: 0.6217
# Validation Accuracy: 0.6194
# Current learning rate: [0.0003125]
# Epoch [73/500], Loss: 2.9054, Train Accuracy: 0.6310
# Validation Accuracy: 0.6218
# Current learning rate: [0.0003125]
# New best model saved at fold 1, epoch 73 with val accuracy: 0.6218
# Epoch [74/500], Loss: 3.1583, Train Accuracy: 0.6366
# Validation Accuracy: 0.6208
# Current learning rate: [0.0003125]
# Epoch [75/500], Loss: 3.2333, Train Accuracy: 0.6338
# Validation Accuracy: 0.6158
# Current learning rate: [0.0003125]
# Epoch [76/500], Loss: 3.2166, Train Accuracy: 0.6335
# Validation Accuracy: 0.6182
# Current learning rate: [0.0003125]
# Epoch [77/500], Loss: 3.2122, Train Accuracy: 0.6309
# Validation Accuracy: 0.6178
# Current learning rate: [0.0003125]
# Epoch [78/500], Loss: 3.2237, Train Accuracy: 0.6307
# Validation Accuracy: 0.6208
# Current learning rate: [0.0003125]
# Epoch [79/500], Loss: 3.4025, Train Accuracy: 0.6297
# Validation Accuracy: 0.6190
# Current learning rate: [0.00015625]
# Epoch [80/500], Loss: 3.2502, Train Accuracy: 0.6237
# Validation Accuracy: 0.6191
# Current learning rate: [0.00015625]
# Epoch [81/500], Loss: 3.4038, Train Accuracy: 0.6240
# Validation Accuracy: 0.6215
# Current learning rate: [0.00015625]
# Epoch [82/500], Loss: 3.1135, Train Accuracy: 0.6253
# Validation Accuracy: 0.6208
# Current learning rate: [0.00015625]
# Epoch [83/500], Loss: 3.1303, Train Accuracy: 0.6308
# Validation Accuracy: 0.6200
# Current learning rate: [0.00015625]
# Epoch [84/500], Loss: 3.3226, Train Accuracy: 0.6318
# Validation Accuracy: 0.6231
# Current learning rate: [0.00015625]
# New best model saved at fold 1, epoch 84 with val accuracy: 0.6231
# Epoch [85/500], Loss: 2.9903, Train Accuracy: 0.6380
# Validation Accuracy: 0.6239
# Current learning rate: [0.00015625]
# New best model saved at fold 1, epoch 85 with val accuracy: 0.6239
# Epoch [86/500], Loss: 3.0952, Train Accuracy: 0.6354
# Validation Accuracy: 0.6232
# Current learning rate: [0.00015625]
# Epoch [87/500], Loss: 3.2539, Train Accuracy: 0.6407
# Validation Accuracy: 0.6250
# Current learning rate: [0.00015625]
# New best model saved at fold 1, epoch 87 with val accuracy: 0.6250
# Epoch [88/500], Loss: 3.0691, Train Accuracy: 0.6371
# Validation Accuracy: 0.6224
# Current learning rate: [0.00015625]
# Epoch [89/500], Loss: 3.1856, Train Accuracy: 0.6413
# Validation Accuracy: 0.6255
# Current learning rate: [0.00015625]
# New best model saved at fold 1, epoch 89 with val accuracy: 0.6255
# Epoch [90/500], Loss: 3.0196, Train Accuracy: 0.6388
# Validation Accuracy: 0.6255
# Current learning rate: [0.00015625]
# Epoch [91/500], Loss: 3.3736, Train Accuracy: 0.6385
# Validation Accuracy: 0.6255
# Current learning rate: [0.00015625]
# Epoch [92/500], Loss: 3.2955, Train Accuracy: 0.6365
# Validation Accuracy: 0.6238
# Current learning rate: [0.00015625]
# Epoch [93/500], Loss: 3.2825, Train Accuracy: 0.6340
# Validation Accuracy: 0.6242
# Current learning rate: [0.00015625]
# Epoch [94/500], Loss: 3.2532, Train Accuracy: 0.6356
# Validation Accuracy: 0.6210
# Current learning rate: [0.00015625]
# Epoch [95/500], Loss: 3.2769, Train Accuracy: 0.6329
# Validation Accuracy: 0.6205
# Current learning rate: [7.8125e-05]
# Epoch [96/500], Loss: 2.8654, Train Accuracy: 0.6346
# Validation Accuracy: 0.6226
# Current learning rate: [7.8125e-05]
# Epoch [97/500], Loss: 3.3809, Train Accuracy: 0.6384
# Validation Accuracy: 0.6269
# Current learning rate: [7.8125e-05]
# New best model saved at fold 1, epoch 97 with val accuracy: 0.6269
# Epoch [98/500], Loss: 2.8788, Train Accuracy: 0.6376
# Validation Accuracy: 0.6228
# Current learning rate: [7.8125e-05]
# Epoch [99/500], Loss: 3.2772, Train Accuracy: 0.6401
# Validation Accuracy: 0.6225
# Current learning rate: [7.8125e-05]
# Epoch [100/500], Loss: 3.1575, Train Accuracy: 0.6435
# Validation Accuracy: 0.6232
# Current learning rate: [7.8125e-05]
# Epoch [101/500], Loss: 3.1362, Train Accuracy: 0.6411
# Validation Accuracy: 0.6238
# Current learning rate: [7.8125e-05]
# Epoch [102/500], Loss: 3.1532, Train Accuracy: 0.6408
# Validation Accuracy: 0.6301
# Current learning rate: [7.8125e-05]
# New best model saved at fold 1, epoch 102 with val accuracy: 0.6301
# Epoch [103/500], Loss: 3.0405, Train Accuracy: 0.6430
# Validation Accuracy: 0.6262
# Current learning rate: [7.8125e-05]
# Epoch [104/500], Loss: 3.2022, Train Accuracy: 0.6409
# Validation Accuracy: 0.6295
# Current learning rate: [7.8125e-05]
# Epoch [105/500], Loss: 3.0224, Train Accuracy: 0.6405
# Validation Accuracy: 0.6252
# Current learning rate: [7.8125e-05]
# Epoch [106/500], Loss: 3.3592, Train Accuracy: 0.6478
# Validation Accuracy: 0.6245
# Current learning rate: [7.8125e-05]
# Epoch [107/500], Loss: 3.1914, Train Accuracy: 0.6405
# Validation Accuracy: 0.6225
# Current learning rate: [7.8125e-05]
# Epoch [108/500], Loss: 3.1684, Train Accuracy: 0.6402
# Validation Accuracy: 0.6259
# Current learning rate: [3.90625e-05]
# Epoch [109/500], Loss: 3.2515, Train Accuracy: 0.6395
# Validation Accuracy: 0.6244
# Current learning rate: [3.90625e-05]
# Epoch [110/500], Loss: 3.2319, Train Accuracy: 0.6434
# Validation Accuracy: 0.6246
# Current learning rate: [3.90625e-05]
# Epoch [111/500], Loss: 3.4049, Train Accuracy: 0.6410
# Validation Accuracy: 0.6229
# Current learning rate: [3.90625e-05]
# Epoch [112/500], Loss: 3.0825, Train Accuracy: 0.6400
# Validation Accuracy: 0.6254
# Current learning rate: [3.90625e-05]
# Epoch [113/500], Loss: 3.0320, Train Accuracy: 0.6422
# Validation Accuracy: 0.6252
# Current learning rate: [3.90625e-05]
# Epoch [114/500], Loss: 3.0784, Train Accuracy: 0.6451
# Validation Accuracy: 0.6264
# Current learning rate: [1.953125e-05]
# Epoch [115/500], Loss: 3.3574, Train Accuracy: 0.6472
# Validation Accuracy: 0.6258
# Current learning rate: [1.953125e-05]
# Epoch [116/500], Loss: 3.2399, Train Accuracy: 0.6416
# Validation Accuracy: 0.6229
# Current learning rate: [1.953125e-05]
# Epoch [117/500], Loss: 3.1810, Train Accuracy: 0.6462
# Validation Accuracy: 0.6265
# Current learning rate: [1.953125e-05]
# Epoch [118/500], Loss: 3.1502, Train Accuracy: 0.6440
# Validation Accuracy: 0.6222
# Current learning rate: [1.953125e-05]
# Epoch [119/500], Loss: 3.1730, Train Accuracy: 0.6431
# Validation Accuracy: 0.6239
# Current learning rate: [1.953125e-05]
# Epoch [120/500], Loss: 3.2926, Train Accuracy: 0.6434
# Validation Accuracy: 0.6270
# Current learning rate: [9.765625e-06]
# Epoch [121/500], Loss: 3.2237, Train Accuracy: 0.6427
# Validation Accuracy: 0.6261
# Current learning rate: [9.765625e-06]
# Epoch [122/500], Loss: 3.2564, Train Accuracy: 0.6451
# Validation Accuracy: 0.6251
# Current learning rate: [9.765625e-06]
# Early stopping at fold 1, epoch 122
#
# Fold 2/5
# Epoch [1/500], Loss: 3.4393, Train Accuracy: 0.4411
# Validation Accuracy: 0.4665
# Current learning rate: [0.01]
# Epoch [2/500], Loss: 3.6262, Train Accuracy: 0.4684
# Validation Accuracy: 0.4676
# Current learning rate: [0.01]
# Epoch [3/500], Loss: 3.5658, Train Accuracy: 0.4590
# Validation Accuracy: 0.5144
# Current learning rate: [0.01]
# Epoch [4/500], Loss: 3.6854, Train Accuracy: 0.4580
# Validation Accuracy: 0.4056
# Current learning rate: [0.01]
# Epoch [5/500], Loss: 3.7319, Train Accuracy: 0.4374
# Validation Accuracy: 0.4001
# Current learning rate: [0.01]
# Epoch [6/500], Loss: 3.6014, Train Accuracy: 0.4450
# Validation Accuracy: 0.4582
# Current learning rate: [0.01]
# Epoch [7/500], Loss: 3.7548, Train Accuracy: 0.4431
# Validation Accuracy: 0.4785
# Current learning rate: [0.01]
# Epoch [8/500], Loss: 3.6478, Train Accuracy: 0.4543
# Validation Accuracy: 0.5061
# Current learning rate: [0.01]
# Epoch [9/500], Loss: 3.4307, Train Accuracy: 0.4729
# Validation Accuracy: 0.4904
# Current learning rate: [0.005]
# Epoch [10/500], Loss: 3.5307, Train Accuracy: 0.4967
# Validation Accuracy: 0.5427
# Current learning rate: [0.005]
# Epoch [11/500], Loss: 3.5225, Train Accuracy: 0.5076
# Validation Accuracy: 0.5536
# Current learning rate: [0.005]
# Epoch [12/500], Loss: 3.4779, Train Accuracy: 0.5042
# Validation Accuracy: 0.5737
# Current learning rate: [0.005]
# Epoch [13/500], Loss: 3.5306, Train Accuracy: 0.4973
# Validation Accuracy: 0.5470
# Current learning rate: [0.005]
# Epoch [14/500], Loss: 3.3155, Train Accuracy: 0.5187
# Validation Accuracy: 0.5741
# Current learning rate: [0.005]
# Epoch [15/500], Loss: 3.3316, Train Accuracy: 0.5276
# Validation Accuracy: 0.4971
# Current learning rate: [0.005]
# Epoch [16/500], Loss: 3.3276, Train Accuracy: 0.5244
# Validation Accuracy: 0.5426
# Current learning rate: [0.005]
# Epoch [17/500], Loss: 3.4260, Train Accuracy: 0.5220
# Validation Accuracy: 0.5360
# Current learning rate: [0.005]
# Epoch [18/500], Loss: 3.3089, Train Accuracy: 0.5316
# Validation Accuracy: 0.5363
# Current learning rate: [0.005]
# Epoch [19/500], Loss: 3.2006, Train Accuracy: 0.5475
# Validation Accuracy: 0.4806
# Current learning rate: [0.005]
# Epoch [20/500], Loss: 3.4887, Train Accuracy: 0.5092
# Validation Accuracy: 0.5553
# Current learning rate: [0.0025]
# Early stopping at fold 2, epoch 20
#
# Fold 3/5
# Epoch [1/500], Loss: 3.4775, Train Accuracy: 0.4452
# Validation Accuracy: 0.5029
# Current learning rate: [0.01]
# Epoch [2/500], Loss: 3.4768, Train Accuracy: 0.4778
# Validation Accuracy: 0.5184
# Current learning rate: [0.01]
# Epoch [3/500], Loss: 3.4509, Train Accuracy: 0.4768
# Validation Accuracy: 0.5250
# Current learning rate: [0.01]
# Epoch [4/500], Loss: 3.5525, Train Accuracy: 0.4667
# Validation Accuracy: 0.4793
# Current learning rate: [0.01]
# Epoch [5/500], Loss: 3.4102, Train Accuracy: 0.4905
# Validation Accuracy: 0.4494
# Current learning rate: [0.01]
# Epoch [6/500], Loss: 3.7929, Train Accuracy: 0.4437
# Validation Accuracy: 0.4124
# Current learning rate: [0.01]
# Epoch [7/500], Loss: 3.4951, Train Accuracy: 0.4593
# Validation Accuracy: 0.3864
# Current learning rate: [0.01]
# Epoch [8/500], Loss: 3.5729, Train Accuracy: 0.4481
# Validation Accuracy: 0.3890
# Current learning rate: [0.01]
# Epoch [9/500], Loss: 3.5611, Train Accuracy: 0.4712
# Validation Accuracy: 0.4170
# Current learning rate: [0.005]
# Epoch [10/500], Loss: 3.4931, Train Accuracy: 0.4983
# Validation Accuracy: 0.5741
# Current learning rate: [0.005]
# Epoch [11/500], Loss: 3.3671, Train Accuracy: 0.5113
# Validation Accuracy: 0.5843
# Current learning rate: [0.005]
# Epoch [12/500], Loss: 3.5283, Train Accuracy: 0.5230
# Validation Accuracy: 0.5529
# Current learning rate: [0.005]
# Epoch [13/500], Loss: 3.5714, Train Accuracy: 0.5047
# Validation Accuracy: 0.5703
# Current learning rate: [0.005]
# Epoch [14/500], Loss: 3.2622, Train Accuracy: 0.5173
# Validation Accuracy: 0.5775
# Current learning rate: [0.005]
# Epoch [15/500], Loss: 3.5347, Train Accuracy: 0.5186
# Validation Accuracy: 0.5550
# Current learning rate: [0.005]
# Epoch [16/500], Loss: 3.3763, Train Accuracy: 0.5191
# Validation Accuracy: 0.5757
# Current learning rate: [0.005]
# Epoch [17/500], Loss: 3.4983, Train Accuracy: 0.5011
# Validation Accuracy: 0.5624
# Current learning rate: [0.0025]
# Epoch [18/500], Loss: 3.3406, Train Accuracy: 0.5439
# Validation Accuracy: 0.6064
# Current learning rate: [0.0025]
# Epoch [19/500], Loss: 3.4979, Train Accuracy: 0.5430
# Validation Accuracy: 0.5913
# Current learning rate: [0.0025]
# Epoch [20/500], Loss: 3.4425, Train Accuracy: 0.5248
# Validation Accuracy: 0.6005
# Current learning rate: [0.0025]
# Early stopping at fold 3, epoch 20
#
# Fold 4/5
# Epoch [1/500], Loss: 3.7021, Train Accuracy: 0.4259
# Validation Accuracy: 0.5109
# Current learning rate: [0.01]
# Epoch [2/500], Loss: 3.6144, Train Accuracy: 0.4541
# Validation Accuracy: 0.5252
# Current learning rate: [0.01]
# Epoch [3/500], Loss: 3.5555, Train Accuracy: 0.4609
# Validation Accuracy: 0.4229
# Current learning rate: [0.01]
# Epoch [4/500], Loss: 3.5682, Train Accuracy: 0.4672
# Validation Accuracy: 0.4379
# Current learning rate: [0.01]
# Epoch [5/500], Loss: 3.3973, Train Accuracy: 0.4661
# Validation Accuracy: 0.4763
# Current learning rate: [0.01]
# Epoch [6/500], Loss: 3.2852, Train Accuracy: 0.4810
# Validation Accuracy: 0.4996
# Current learning rate: [0.01]
# Epoch [7/500], Loss: 3.4672, Train Accuracy: 0.4854
# Validation Accuracy: 0.3610
# Current learning rate: [0.01]
# Epoch [8/500], Loss: 3.4881, Train Accuracy: 0.4853
# Validation Accuracy: 0.4823
# Current learning rate: [0.005]
# Epoch [9/500], Loss: 3.4477, Train Accuracy: 0.4991
# Validation Accuracy: 0.5561
# Current learning rate: [0.005]
# Epoch [10/500], Loss: 3.4343, Train Accuracy: 0.5195
# Validation Accuracy: 0.5706
# Current learning rate: [0.005]
# Epoch [11/500], Loss: 3.5602, Train Accuracy: 0.5038
# Validation Accuracy: 0.5699
# Current learning rate: [0.005]
# Epoch [12/500], Loss: 3.3022, Train Accuracy: 0.5227
# Validation Accuracy: 0.5655
# Current learning rate: [0.005]
# Epoch [13/500], Loss: 3.5656, Train Accuracy: 0.5079
# Validation Accuracy: 0.5414
# Current learning rate: [0.005]
# Epoch [14/500], Loss: 3.5052, Train Accuracy: 0.5179
# Validation Accuracy: 0.5470
# Current learning rate: [0.005]
# Epoch [15/500], Loss: 3.3887, Train Accuracy: 0.5131
# Validation Accuracy: 0.5827
# Current learning rate: [0.005]
# Epoch [16/500], Loss: 3.4422, Train Accuracy: 0.5196
# Validation Accuracy: 0.5624
# Current learning rate: [0.005]
# Epoch [17/500], Loss: 3.2558, Train Accuracy: 0.5367
# Validation Accuracy: 0.5506
# Current learning rate: [0.005]
# Epoch [18/500], Loss: 3.5534, Train Accuracy: 0.5112
# Validation Accuracy: 0.5154
# Current learning rate: [0.005]
# Epoch [19/500], Loss: 3.5969, Train Accuracy: 0.5048
# Validation Accuracy: 0.5064
# Current learning rate: [0.005]
# Epoch [20/500], Loss: 3.4057, Train Accuracy: 0.5040
# Validation Accuracy: 0.5306
# Current learning rate: [0.005]
# Early stopping at fold 4, epoch 20
#
# Fold 5/5
# Epoch [1/500], Loss: 3.5542, Train Accuracy: 0.4431
# Validation Accuracy: 0.5521
# Current learning rate: [0.01]
# Epoch [2/500], Loss: 3.5200, Train Accuracy: 0.4699
# Validation Accuracy: 0.5184
# Current learning rate: [0.01]
# Epoch [3/500], Loss: 3.4243, Train Accuracy: 0.4934
# Validation Accuracy: 0.2162
# Current learning rate: [0.01]
# Epoch [4/500], Loss: 3.5781, Train Accuracy: 0.4543
# Validation Accuracy: 0.4283
# Current learning rate: [0.01]
# Epoch [5/500], Loss: 3.6042, Train Accuracy: 0.4506
# Validation Accuracy: 0.5361
# Current learning rate: [0.01]
# Epoch [6/500], Loss: 3.5655, Train Accuracy: 0.4590
# Validation Accuracy: 0.4993
# Current learning rate: [0.01]
# Epoch [7/500], Loss: 3.7238, Train Accuracy: 0.4647
# Validation Accuracy: 0.4220
# Current learning rate: [0.005]
# Epoch [8/500], Loss: 3.5941, Train Accuracy: 0.4654
# Validation Accuracy: 0.5576
# Current learning rate: [0.005]
# Epoch [9/500], Loss: 3.5052, Train Accuracy: 0.4966
# Validation Accuracy: 0.5680
# Current learning rate: [0.005]
# Epoch [10/500], Loss: 3.3465, Train Accuracy: 0.5176
# Validation Accuracy: 0.5780
# Current learning rate: [0.005]
# Epoch [11/500], Loss: 3.2981, Train Accuracy: 0.5243
# Validation Accuracy: 0.5470
# Current learning rate: [0.005]
# Epoch [12/500], Loss: 3.3579, Train Accuracy: 0.5254
# Validation Accuracy: 0.5870
# Current learning rate: [0.005]
# Epoch [13/500], Loss: 3.5651, Train Accuracy: 0.5146
# Validation Accuracy: 0.5060
# Current learning rate: [0.005]
# Epoch [14/500], Loss: 3.4729, Train Accuracy: 0.5123
# Validation Accuracy: 0.5509
# Current learning rate: [0.005]
# Epoch [15/500], Loss: 3.2352, Train Accuracy: 0.5231
# Validation Accuracy: 0.5766
# Current learning rate: [0.005]
# Epoch [16/500], Loss: 3.5367, Train Accuracy: 0.5158
# Validation Accuracy: 0.5641
# Current learning rate: [0.005]
# Epoch [17/500], Loss: 3.5310, Train Accuracy: 0.5037
# Validation Accuracy: 0.5284
# Current learning rate: [0.005]
# Epoch [18/500], Loss: 3.4185, Train Accuracy: 0.5245
# Validation Accuracy: 0.5591
# Current learning rate: [0.0025]
# Epoch [19/500], Loss: 3.2728, Train Accuracy: 0.5328
# Validation Accuracy: 0.6066
# Current learning rate: [0.0025]
# Epoch [20/500], Loss: 3.4767, Train Accuracy: 0.5512
# Validation Accuracy: 0.5998
# Current learning rate: [0.0025]
# Early stopping at fold 5, epoch 20
# Best model saved with validation accuracy: 0.6301

# %% [markdown]
# # 11: 학습 및 검증 루프

# %% [markdown]
# # 12: 테스트 데이터 예측 수행

# %%
# - 가장 성능이 좋은 모델을 로드하고 테스트 데이터에 대한 예측을 수행
model.load_state_dict(torch.load('best_model.pth'))  # 가장 성능이 좋은 모델 로드
model.eval()
predictions = []

with torch.no_grad():
    test = np.load('drive/MyDrive/Colab Notebooks/AiChallenge/2024-ai-challenge/testset.npy')  # 테스트 데이터 불러오기
    test_dataset = CustomDataset(test, np.zeros((test.shape[0], 100)), transform=transform)
    test_loader = DataLoader(test_dataset, batch_size=1024, shuffle=False, num_workers=multiprocessing.cpu_count())

    for test_features, _ in test_loader:
        test_features = test_features.cuda()
        outputs = model(test_features)
        predictions.append(outputs.cpu().numpy())

# 예측 결과 합치기
predictions = np.concatenate(predictions, axis=0)

# 예측된 클래스의 인덱스를 얻음
predicted_classes = np.argmax(predictions, axis=1)

# 결과를 DataFrame으로 변환
submission_df = pd.DataFrame({
    'id_idx': np.arange(len(predicted_classes)),
    'label': predicted_classes
})

# CSV 파일로 저장
submission_filename = 'submission.csv'
submission_df.to_csv(submission_filename, index=False)

print(f"Submission file has been saved as '{submission_filename}'")
# Out:
# <ipython-input-58-a99326181498>:2: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load('best_model.pth'))  # 가장 성능이 좋은 모델 로드
# Submission file has been saved as 'submission.csv'
